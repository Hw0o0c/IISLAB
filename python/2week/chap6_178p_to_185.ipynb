# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt

# %%
filepath = "C:/data/bicycle.csv"

# %%
df = pd.read_csv(filepath, engine='python', encoding='cp949')

# %%
df
# Out:
#              자전거번호                 대여일시  대여 대여소번호              대여 대여소명  대여거치대  \
# 0        SPB-44695  2022-12-01 00:00:10      1933         개봉푸르지오아파트 상가      0
# 1        SPB-31562  2022-12-01 00:00:04      3007                MBC 앞      0
# 2        SPB-56324  2022-12-01 00:01:33      4468             가락1동주민센터      0
# 3        SPB-30175  2022-12-01 00:03:02       652     답십리 래미안엘파인아파트 입구      0
# 4        SPB-37639  2022-12-01 00:00:18      1047            강동 한신휴플러스      0
# ...            ...                  ...       ...                  ...    ...
# 1815385  SPB-30272  2022-12-31 19:48:21      1906         신도림역 1번 출구 앞      0
# 1815386  SPB-65828  2022-12-31 11:59:43      5858             영등포역5번출구      0
# 1815387  SPB-33852  2022-12-31 21:56:32      2635           잠실새내역 1번출구      0
# 1815388  SPB-55558  2022-12-31 22:30:52      2325        대치삼성아파트 앞 교차로      0
# 1815389  SPB-42935  2022-12-31 23:33:22      2423  영희초교 사거리(래미안개포루체하임)      0
#
# ...

# %%
plt.boxplot(df['이용거리(M)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22fba9196c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22fba9f9660>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22fb94814b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22fb93c44f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22fb93c4790>],
#  'means': []}

# %%
df
# Out:
#              자전거번호                 대여일시  대여 대여소번호              대여 대여소명  대여거치대  \
# 0        SPB-44695  2022-12-01 00:00:10      1933         개봉푸르지오아파트 상가      0
# 1        SPB-31562  2022-12-01 00:00:04      3007                MBC 앞      0
# 2        SPB-56324  2022-12-01 00:01:33      4468             가락1동주민센터      0
# 3        SPB-30175  2022-12-01 00:03:02       652     답십리 래미안엘파인아파트 입구      0
# 4        SPB-37639  2022-12-01 00:00:18      1047            강동 한신휴플러스      0
# ...            ...                  ...       ...                  ...    ...
# 1815385  SPB-30272  2022-12-31 19:48:21      1906         신도림역 1번 출구 앞      0
# 1815386  SPB-65828  2022-12-31 11:59:43      5858             영등포역5번출구      0
# 1815387  SPB-33852  2022-12-31 21:56:32      2635           잠실새내역 1번출구      0
# 1815388  SPB-55558  2022-12-31 22:30:52      2325        대치삼성아파트 앞 교차로      0
# 1815389  SPB-42935  2022-12-31 23:33:22      2423  영희초교 사거리(래미안개포루체하임)      0
#
# ...

# %%
df.duplicated(['이용거리(M)'])
# Out:
# 0          False
# 1          False
# 2           True
# 3           True
# 4          False
#            ...
# 1815385    False
# 1815386     True
# 1815387     True
# 1815388     True
# 1815389     True
# Length: 1815390, dtype: bool

# %%
df.duplicated(['이용거리(M)'], keep='first')
# Out:
# 0          False
# 1          False
# 2           True
# 3           True
# 4          False
#            ...
# 1815385    False
# 1815386     True
# 1815387     True
# 1815388     True
# 1815389     True
# Length: 1815390, dtype: bool

# %%
df.duplicated(['이용거리(M)'], keep='last')
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1815385    False
# 1815386     True
# 1815387     True
# 1815388     True
# 1815389    False
# Length: 1815390, dtype: bool

# %%
df.duplicated(['이용거리(M)'], keep=False)
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1815385    False
# 1815386     True
# 1815387     True
# 1815388     True
# 1815389     True
# Length: 1815390, dtype: bool

# %%
df.drop_duplicates(['이용거리(M)'],keep='first')
# Out:
#              자전거번호                 대여일시  대여 대여소번호             대여 대여소명  대여거치대  \
# 0        SPB-44695  2022-12-01 00:00:10      1933        개봉푸르지오아파트 상가      0
# 1        SPB-31562  2022-12-01 00:00:04      3007               MBC 앞      0
# 4        SPB-37639  2022-12-01 00:00:18      1047           강동 한신휴플러스      0
# 6        SPB-31850  2022-12-01 00:00:09       646           장한평역 1번출구      0
# 7        SPB-36226  2022-12-01 00:00:06      1175         대한항공 인력개발센터      0
# ...            ...                  ...       ...                 ...    ...
# 1815361  SPB-51832  2022-12-31 23:08:30       421              마포구청 앞      0
# 1815365  SPB-53073  2022-12-31 23:13:47      2140            신림1교 교차로      0
# 1815376  SPB-38597  2022-12-31 23:54:58      4497       아시아선수촌아파트 교차로      0
# 1815379  SPB-55054  2022-12-31 22:30:39      1960  구로거리공원 동측(신도림역 방면)      0
# 1815385  SPB-30272  2022-12-31 19:48:21      1906        신도림역 1번 출구 앞      0
#
# ...
