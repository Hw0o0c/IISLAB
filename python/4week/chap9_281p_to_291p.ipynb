# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

# %%
file_path = "C:/data/titanic.csv"
df=pd.read_csv(file_path)

# %%
sns.catplot(x='Sex', y='Age', kind='bar',data=df)

# %%
sns.violinplot(x='Sex', y='Age', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
bins = [1, 20, 60, 100]

# %%
df_Age = pd.cut(df["Age"], bins, labels = ["minority", "majority", "old age"])

# %%
df["Age_class"]=df_Age

# %%
sns.catplot(x="Sex", hue="Age_class", kind="count", data=df)

# %%
sns.catplot(x="Survived", hue="Age_class", kind="count", data=df)

# %%
sns.catplot(x="Age_class", hue="Survived", kind="count", data=df)

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
df['Fare'].hist()
# Out:
# <Axes: >

# %%
sns.catplot(x='Survived', kind='count', hue='Sex', data=df)

# %%
df['Survivor'] = df['Survived'].map({0:'no', 1:'yes'})
sns.catplot(x='Survivor', kind='count', hue='Sex', data=df)

# %%
sns.catplot(x='Sex', kind='count', hue='Survivor', data=df)

# %%
sns.catplot(x='Pclass', kind='count', hue='Survivor', data=df)

# %%
sns.catplot(x='Embarked', kind='count', hue='Survivor', data=df)

# %%
sns.catplot(x='Age', kind='count', hue='Survivor', data=df.loc[df['Age'] < 20])

# %%
sns.catplot(x='Age', kind='count', hue='Survivor', data=df[df['Age']>=70])

# %%
sns.catplot(x='Age', y='Survived', hue='Sex',data=df.loc[df['Age']>=20])

# %%
Pg = sns.PairGrid(df, y_vars="Survived",
                 x_vars=["Pclass", "Sex", "Embarked", "Age_class"],
                 height=5, aspect=.7)
Pg.map(sns.pointplot, scale=1.3, errwidth=4, color="xkcd:plum")
Pg.set(ylim = plt.ylim(0,1))
sns.despine(fig=Pg.fig, left=True)
plt.rc('font', family='Malgun Gothic')

# %%
Pg = sns.PairGrid(df, y_vars="Survived", x_vars=["Pclass", "Sex", "Embarked", "Age_class"],
                 height=5, aspect=.7)
Pg.map(sns.barplot)

# %%
Pg.map(sns.violinplot)

# %%
sns.displot(df['Age'].loc[df['Sex']=='male'])
sns.displot(df['Age'].loc[df['Sex']=='female'])

# %%
sns.catplot(x='Age', kind='count', hue='Survivor', data=df)

# %%
sns.lmplot(x='SibSp', y='Survived', hue='Sex', data=df)
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\ADMIN\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\ADMIN\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked Age_class Survivor
# 0        0         A/5 21171   7.2500   NaN        S  majority       no
# 1        0          PC 17599  71.2833   C85        C  majority      yes
# 2        0  STON/O2. 3101282   7.9250   NaN        S  majority      yes
# 3        0            113803  53.1000  C123        S  majority      yes
# 4        0            373450   8.0500   NaN        S  majority       no
# ..     ...               ...      ...   ...      ...       ...      ...
# 886      0            211536  13.0000   NaN        S  majority       no
# 887      0            112053  30.0000   B42        S  minority      yes
# 888      2        W./C. 6607  23.4500   NaN        S       NaN       no
# 889      0            111369  30.0000  C148        C  majority      yes
# 890      0            370376   7.7500   NaN        Q  majority       no
#
# [891 rows x 14 columns]

# %%
df['family_Size'] = df['SibSp'] + df['Parch']

# %%
sns.lmplot(x='family_Size', y='Survived',hue='Sex', data=df)

# %%
sns.lmplot(x='Fare', y='Survived', hue='Sex', data=df)

# %%
def bar_chart(feature):
    Survived = df[df['Survived']==1][feature].value_counts()
    Dead = df[df['Survived']==0][feature].value_counts()
    df_titanic = pd.DataFrame([Survived, Dead])
    df_titanic.index = ['Survived', 'Dead']
    df_titanic.plot(kind='bar', stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %%
bar_chart('Pclass')

# %%
bar_chart('Embarked')
